# %% [markdown]
# <img src='attachment:logo.jpg' width="200" height="100" style="float:right"></img>

# %% [markdown]
# # Practice Exercise questions

# %% [markdown]
# # 1
#
# A survey of magazine subscribers showed that 45.8% rented a car during the past 12 months for business purposes, 54% rented a car for personal reasons, and 30% for both personal & business reasons.
#
# a.	What is the prob. That a subscriber rented a car for both business or personal reasons.
#
# b.	What is the prob. That a subscriber did not rent a car for either business or personal reasons.

# %%
import numpy as np
import pandas as pd
import scipy.stats as ss

# %% [markdown]
# **a) What is the prob. That a subscriber rented a car for both business or personal reasons.**

# %%
probab_rented_car_business= 0.458
probab_rented_car_personal= 0.540
probab_rented_car_business_personal= 0.30

# %% [markdown]
# **P(A or B) = P(A) + P(B) - P(A and B)**

# %%
probab_rented_car_business_or_personal= probab_rented_car_business+probab_rented_car_personal-probab_rented_car_business_personal

print('The Probability % that a subscriber rented a car for both business or personal reasons is',probab_rented_car_business_or_personal*100,'%')
# Out:
# The Probability % that a subscriber rented a car for both business or personal reasons is 69.8 %

# %% [markdown]
# **b) What is the prob. That a subscriber did not rent a car for either business or personal reasons**

# %% [markdown]
# **Complement Rule**
#
# **Complement of P(A) = 1 - P(A)**

# %%
print('The Probability % that a subscriber did not rent a car for either business or personal reasons is',round((1-probab_rented_car_business_or_personal),4)*100,'%')
# Out:
# The Probability % that a subscriber did not rent a car for either business or personal reasons is 30.2 %

# %% [markdown]
# # 2
#
#
# NBA shooter converts 93% of its shots. During the game the same NBA shooter is fouled and is awarded two shots.
#
# a.	What is the prob. That he will make both shots.
#
# b.	What is the prob. That he will make at least one shot.
#
# c.	What is the prob. That he will miss both shots.

# %%
success=0.93

# %% [markdown]
# **a) What is the prob. That he will make both shots**

# %%
print('The prob. % that he will make both shots is',round(ss.binom.pmf(2,2,0.93),5)*100,'%')
# Out:
# The prob. % that he will make both shots is 86.49 %

# %% [markdown]
# **b) What is the prob. That he will make at least one shot**

# %%
print('The prob. % that he will make at least one shot is',round(ss.binom.cdf(1,2,0.93),5)*100,'%')
# Out:
# The prob. % that he will make at least one shot is 13.51 %

# %% [markdown]
# **c) What is the prob. That he will miss both shots**

# %%
print('The prob. % that he will miss both shots is',round(ss.binom.cdf(0,2,0.93),5)*100,'%')
# Out:
# The prob. % that he will miss both shots is 0.49 %

# %% [markdown]
# # 3
#
#
# Visa Card studied how frequently, young consumers, ages 18-24, use plastic cards. The results provided the following probabilities.
#
# •	Prob. That a consumer uses a plastic card when making a purchase .37
#
# •	Given that consumer uses a plastic card, there is a .19 prob. That the consumer is 18-24 years old.
#
# •	Given that consumer uses a plastic card, there is a .81 prob. That the consumer is 24+ years old.
#
# •	14% of the consumer population is b/w 18-24 years
#
# a)	Given the consumer is b/w 18-24, what is the prob. that the consumer uses plastic card
#
# b)	Given the consumer is 24+, what is the prob. that the consumer uses plastic card
#
# c)	What is the interpretations of the probabilities shown above.

# %%
probab_of_using_p_cards=0.37
probab_of_18_24_using_p_cards= 0.19
probab_of_24plus_using_p_cards= 0.81
probab_consumer_18_24=0.14

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **a) Given the consumer is b/w 18-24, what is the prob. that the consumer uses plastic card**

# %%
probab_of_p_cards_given_that_18_24 = 0.070/0.14

round(probab_of_p_cards_given_that_18_24*100,2)
# Out:
# 50.0

# %% [markdown]
# **b) Given the consumer is 24+, what is the prob. that the consumer uses plastic card**

# %%
probab_of_p_cards_given_that_24_plus = 0.299/0.86

round(probab_of_p_cards_given_that_24_plus*100,2)
# Out:
# 34.77

# %% [markdown]
# **c) What is the interpretations of the probabilities shown above**

# %% [markdown]
# About 50% of Consumers within 18-24 Age Group use plastic cards and do not have enough credit history and reponsibilities to pay off credit card bills. Thus, the company should avoid providing credit cards for Consumers belonging to this age group.
#
# On the other hand, the consumers in this age group have relatively lesser responsibilities and can do reckless shopping. This will increase the company's credit card usage.

# %% [markdown]
# # 4
#
# A local bank reviewed its credit card policy with the intention of recalling some of its credit cards. In the past approx. 5% of cardholders defaulted, leaving the bank unable to collect outstanding balance. Hence, management established a prior probability of 0.05 that any particular cardholder will default. The bank also found that the probability of missing a monthly payment is .20 for customers who do not default. Of course, the probability of missing a monthly payment for those who default is 0.5.
#
# Q: Given that a customer missed one or more monthly payments, compute the prob.
# That a customer will default

# %%
probab_default= 0.05
probab_missed_and_no_default=0.20
probab_missed_given_default=0.50

# %% [markdown]
# **Bayes' Theorem**
#
# <img style="width:25%" src='attachment:image.png'></img>

# %%
probability_of_missed= 
(probab_missed_and_no_default*(1-probab_default)) + (probab_missed_given_default*probab_default)

# %%
probab_default_given_missed= (probab_missed_given_default * probab_default )/ probability_of_missed

# %%
round(probab_default_given_missed,4)*100 #probab percentage
# Out:
# 11.63

# %% [markdown]
# # 5
#
# The census current population survey shows 28% of individuals , ages 25 and older have completed 4 years of college. For a sample of 15 individuals, ages 25 and older, answer the following.
#
# A) What is the prob. 4 will have completed four years of college
#
# B) What is the prob. 3 or more will have completed 4 years of college

# %%
p=0.28
n=15

# %% [markdown]
# **A) What is the prob. 4 will have completed four years of college**

# %%
print('The Probability % that 4 will  have completed four years of college is',round(ss.binom.pmf(4,n,p),3)*100,'%')
# Out:
# The Probability % that 4 will  have completed four years of college is 22.6 %

# %% [markdown]
# **B) What is the prob. 3 or more will have completed 4 years of college**

# %%
print('The Probability % that  3 or more will have completed 4 years of college is',round(1-ss.binom.cdf(2,n,p),3)*100,'%')
# Out:
# The Probability % that  3 or more will have completed 4 years of college is 83.5 %

# %% [markdown]
# # 6
#
# An average of 15 aircrafts accidents occur each year. Compute the following
#
# a)	Mean number of aircraft accidents during a month.
#
# b)	Probability of no accidents during a month.
#
# c)	Probability of exactly one accident during a month.
#
# d)	Probability of more than one accident during a month.

# %%
l=15

# %% [markdown]
# **a) Mean number of aircraft accidents during a month.**

# %%
print('The Mean number of aircraft accidents during a month is', l*1/12)
# Out:
# The Mean number of aircraft accidents during a month is 1.25

# %% [markdown]
# **b) Probability of no accidents during a month.**

# %%
print('The Probability % of no accidents during a month is',round(ss.poisson.cdf(0,1.25),4)*100,'%')
# Out:
# The Probability % of no accidents during a month is 28.65 %

# %% [markdown]
# **c) Probability of exactly one accident during a month.**

# %%
print('The Probability % of exactly one accidents during a month is',round(ss.poisson.pmf(1,1.25),3)*100,'%')
# Out:
# The Probability % of exactly one accidents during a month is 35.8 %

# %% [markdown]
# **d) Probability of more than one accident during a month.**

# %%
print('The Probability % of more than one accidents during a month is',round(1-ss.poisson.cdf(1,1.25),3)*100,'%')
# Out:
# The Probability % of more than one accidents during a month is 35.5 %

# %% [markdown]
# # 7
#
# During early 2012, economic hardship was stretching the limits of France welfare system. One indicator of the level of hardship was the increase in the number of people bringing items to the pawnbroker.  Assume the number of people visiting the pawnshop is normally distributed with the mean of 658.
#
# a)	Suppose you learn that on 3% of days, 610 or fewer people bought items to the pawnshop. What is the S.d. of the no. of people bringing items to the pawnshop.
#
# b)	On any given day, what is the prob. That b/w 600 and 700 people bring items to the pawnshop
#
# c)	How many people bring items to the pawnshop on the busiest 3% of days.

# %% [markdown]
# **a) Suppose you learn that on 3% of days, 610 or fewer people bought items to the pawnshop. What is the S.d. of the no. of people bringing items to the pawnshop.**

# %%
mu=658
x=610

# %%
z=ss.norm.ppf(0.03) #finding the corresponding z value using ppf for 3%

# %% [markdown]
# $
# z= \dfrac{x-\mu}{\sigma}
# $

# %%
sigma= (x - mu)/z
round(sigma,2)
# Out:
# 25.52

# %% [markdown]
# **b) On any given day, what is the prob. That b/w 600 and 700 people bring items to the pawnshop**

# %%
print('On any given day, the prob % that b/w 600 and 700 people bring items to the pawnshop is',round(ss.norm.cdf(700,mu,sigma)-ss.norm.cdf(600,mu,sigma),2)*100,'%')
# Out:
# On any given day, the prob % that b/w 600 and 700 people bring items to the pawnshop is 94.0 %

# %% [markdown]
# **c) How many people bring items to the pawnshop on the busiest 3% of days.**

# %%
p=1-0.03 # 97%  will be less than the top 3% busiest days' rush

z=ss.norm.ppf(p)#getting z value for 97%

# %%
print('The number of people bringing items to the pawnshop on the busiest 3% of days are',z*sigma+mu)
# Out:
# The number of people bringing items to the pawnshop on the busiest 3% of days are 706.0

# %% [markdown]
#                                              Happy Learning
