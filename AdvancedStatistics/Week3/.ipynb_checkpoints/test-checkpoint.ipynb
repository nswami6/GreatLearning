# %%
#Import all the necessary modules
#Import all the necessary modules
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_df = pd.read_csv("FB.csv")
data_df.head(10)
# Out:
#                           status_id  num_reactions  num_comments  num_shares  \
# 0  246675545449582_1649696485147474            529           512         262
# 1  246675545449582_1649426988507757            150             0           0
# 2  246675545449582_1648730588577397            227           236          57
# 3  246675545449582_1648576705259452            111             0           0
# 4  246675545449582_1645700502213739            213             0           0
# 5  246675545449582_1645650162218773            217             6           0
# 6  246675545449582_1645564175560705            503           614          72
# 7  246675545449582_1644824665634656            295           453          53
# 8  246675545449582_1644655795651543            203             1           0
# 9  246675545449582_1638788379571618            170             9           1
#
#    num_likes  num_loves  num_wows  num_hahas  num_sads  num_angrys  \
# 0        432         92         3          1         1           0
# 1        150          0         0          0         0           0
# 2        204         21         1          1         0           0
# 3        111          0         0          0         0           0
# 4        204          9         0          0         0           0
# 5        211          5         1          0         0           0
# 6        418         70        10          2         0           3
# 7        260         32         1          1         0           1
# 8        198          5         0          0         0           0
# 9        167          3         0          0         0           0
#
#    status_link  status_photo  status_status
# 0            0             0              0
# 1            0             1              0
# 2            0             0              0
# 3            0             1              0
# 4            0             1              0
# 5            0             1              0
# 6            0             0              0
# 7            0             0              0
# 8            0             1              0
# 9            0             1              0

# %%
data_df.shape
# Out:
# (7050, 13)

# %%
data_df.dtypes
# Out:
# status_id        object
# num_reactions     int64
# num_comments      int64
# num_shares        int64
# num_likes         int64
# num_loves         int64
# num_wows          int64
# num_hahas         int64
# num_sads          int64
# num_angrys        int64
# status_link       int64
# status_photo      int64
# status_status     int64
# dtype: object

# %%
data_df.describe()
# Out:
#        num_reactions  num_comments   num_shares    num_likes    num_loves  \
# count    7050.000000   7050.000000  7050.000000  7050.000000  7050.000000
# mean      230.117163    224.356028    40.022553   215.043121    12.728652
# std       462.625309    889.636820   131.599965   449.472357    39.972930
# min         0.000000      0.000000     0.000000     0.000000     0.000000
# 25%        17.000000      0.000000     0.000000    17.000000     0.000000
# 50%        59.500000      4.000000     0.000000    58.000000     0.000000
# 75%       219.000000     23.000000     4.000000   184.750000     3.000000
# max      4710.000000  20990.000000  3424.000000  4710.000000   657.000000
#
#           num_wows    num_hahas     num_sads   num_angrys  status_link  \
# count  7050.000000  7050.000000  7050.000000  7050.000000  7050.000000
# mean      1.289362     0.696454     0.243688     0.113191     0.008936
# std       8.719650     3.957183     1.597156     0.726812     0.094115
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max     278.000000   157.000000    51.000000    31.000000     1.000000
#
#        status_photo  status_status
# count   7050.000000    7050.000000
# mean       0.608227       0.051773
# std        0.488181       0.221584
# min        0.000000       0.000000
# 25%        0.000000       0.000000
# 50%        1.000000       0.000000
# 75%        1.000000       0.000000
# max        1.000000       1.000000

# %%
data_df.duplicated().sum()
# Out:
# 53

# %%
data_df.drop_duplicates(inplace=True)
data_df.corr(method='pearson')
# Out:
#                num_reactions  num_comments  num_shares  num_likes  num_loves  \
# num_reactions       1.000000      0.156218    0.259680   0.994672   0.310690
# num_comments        0.156218      1.000000    0.640528   0.105964   0.521310
# num_shares          0.259680      0.640528    1.000000   0.179705   0.820279
# num_likes           0.994672      0.105964    0.179705   1.000000   0.212760
# num_loves           0.310690      0.521310    0.820279   0.212760   1.000000
# num_wows            0.261717      0.163498    0.409797   0.200039   0.510144
# num_hahas           0.179681      0.325056    0.399855   0.123154   0.507892
# num_sads            0.082112      0.257537    0.218618   0.057129   0.226564
# num_angrys          0.136084      0.239549    0.332347   0.096298   0.394810
# status_link         0.030557     -0.023479   -0.025894   0.034635  -0.029596
# status_photo       -0.144434     -0.292059   -0.354980  -0.112900  -0.352689
# status_status       0.111832     -0.049279   -0.066380   0.121497  -0.065089
#
#                num_wows  num_hahas  num_sads  num_angrys  status_link  \
# num_reactions  0.261717   0.179681  0.082112    0.136084     0.030557
# num_comments   0.163498   0.325056  0.257537    0.239549    -0.023479
# num_shares     0.409797   0.399855  0.218618    0.332347    -0.025894
# num_likes      0.200039   0.123154  0.057129    0.096298     0.034635
# num_loves      0.510144   0.507892  0.226564    0.394810    -0.029596
# num_wows       1.000000   0.288463  0.091419    0.191667    -0.011609
# num_hahas      0.288463   1.000000  0.154029    0.225077    -0.015996
# num_sads       0.091419   0.154029  1.000000    0.143704    -0.014973
# num_angrys     0.191667   0.225077  0.143704    1.000000    -0.015252
# status_link   -0.011609  -0.015996 -0.014973   -0.015252     1.000000
# status_photo  -0.090285  -0.159739 -0.089065   -0.126767    -0.118278
# status_status -0.001998  -0.034360  0.018574   -0.028746    -0.022167
#
#                status_photo  status_status
# num_reactions     -0.144434       0.111832
# num_comments      -0.292059      -0.049279
# num_shares        -0.354980      -0.066380
# num_likes         -0.112900       0.121497
# num_loves         -0.352689      -0.065089
# num_wows          -0.090285      -0.001998
# num_hahas         -0.159739      -0.034360
# num_sads          -0.089065       0.018574
# num_angrys        -0.126767      -0.028746
# status_link       -0.118278      -0.022167
# status_photo       1.000000      -0.288571
# status_status     -0.288571       1.000000

# %%
data_df.boxplot(figsize=(20,3))
# Out:
# <AxesSubplot:>

# %%
data_df['status_status'].value_counts()
# Out:
# 0    6638
# 1     359
# Name: status_status, dtype: int64
