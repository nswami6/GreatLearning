# %% [markdown]
# ## A Tech-support call-center wants to know based on the certain variables whether an employee can be promoted or not. Create a model using Random Forest to predict whether an employee will be promoted or not.
#
#
#
# **Dataset Description**
#
#     Feature 		Definition
#     employee_id		Unique ID for employee
#     department		Department of employee
#     education		Education Level
#     gender			Gender of Employee
#     no_of_trainings		no of other trainings completed in previous year on soft skills, technical skills etc.
#     age	     		Age of Employee
#     last_promotion_rating	Employee Rating for the previous year
#     employee_since_years	Length of service in years
#     all_tasks_completed	If employee has completed all the tasks assigned to him/her
#     training_marks		Marks in current year's training evaluations
#     is_promoted		(Target)To promote or not

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# **Get the data**

# %%
df = pd.read_csv("hrdata.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  employee_id         department         education gender  \
# 0           0      2001001  Sales & Marketing  Master's & above      f
# 1           1      2001002         Operations        Bachelor's      m
# 2           2      2001003  Sales & Marketing        Bachelor's      m
# 3           3      2001004  Sales & Marketing        Bachelor's      m
# 4           4      2001005         Technology        Bachelor's      m
#
#    no_of_trainings  age  last_promotion_rating  employee_since_years  \
# 0                1   35                      5                     8
# 1                1   30                      5                     4
# 2                1   34                      3                     7
# 3                2   39                      1                    10
# 4                1   45                      3                     2
#
#    all_tasks_completed  training_marks  is_promoted
# 0                    1              49            0
# 1                    0              60            0
# 2                    0              50            0
# 3                    0              50            0
# 4                    0              73            0

# %%
df.shape
# Out:
# (48660, 18)

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.dtypes.value_counts()
# Out:
# int64     8
# object    3
# dtype: int64

# %% [markdown]
# **Check for Null values**

# %%
df.isnull().sum()
# Out:
# employee_id              0
# department               0
# education                0
# gender                   0
# no_of_trainings          0
# age                      0
# last_promotion_rating    0
# employee_since_years     0
# all_tasks_completed      0
# training_marks           0
# is_promoted              0
# dtype: int64

# %% [markdown]
# ## EDA

# %% [markdown]
# **Plot bar chart of target variable**

# %%
df1=df[['is_promoted','employee_id']].groupby(by=['is_promoted']).count().rename(columns={"employee_id":"Employee_count"}).reset_index()
df1
sns.barplot(df1['is_promoted'],df1['Employee_count'])

# %% [markdown]
# **Check % of 0s and 1s in Target variable**

# %%
df.is_promoted.value_counts(normalize=True)
# Out:
# 0    0.913029
# 1    0.086971
# Name: is_promoted, dtype: float64

# %% [markdown]
# ##### Inference: Data seems to be highly imbalanced with only 8% of 1s in target variable

# %% [markdown]
# **Check the gender distribution**

# %%
# df2=df[['gender','employee_id','is_promoted']].groupby(by=['is_promoted','gender']).count().rename(columns={"employee_id":"Employee_count"}).reset_index()

# sns.barplot(df2['is_promoted'],df2['Employee_count'],hue=df2['gender'])
# df2
df['gender'].hist()

# %% [markdown]
# **Check distribution of continuous variables**

# %%
continuous=df.dtypes[df.dtypes=='int64'].index

sns.pairplot(df[continuous].drop(['employee_id','is_promoted'],axis=1),diag_kind='kde')
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# **Plot gender with target variable**

# %%
sns.countplot(df.is_promoted,hue=df.gender,palette='BuPu_r')
plt.show()

# %% [markdown]
# **Plot Employee Since vs Training marks**
#
# set hue as is_promoted

# %%
plt.figure(figsize=(20,15))
sns.barplot(df.employee_since_years,df.training_marks, hue=df.is_promoted,ci=False)
plt.show()

# %% [markdown]
# **Check for outliers**

# %%
data_plot=df[continuous].drop('is_promoted',axis=1)
fig=plt.figure(figsize=(12,7))
for i in range(0,len(data_plot.columns)):
    ax=fig.add_subplot(2,4,i+1)
    sns.boxplot(y=data_plot[data_plot.columns[i]])
    ax.set_title(data_plot.columns[i],color='Red')
    plt.grid()
plt.tight_layout()

# %% [markdown]
# **There are many outliers in the employee_since_years, age and no_trainings**

# %% [markdown]
# **Convert Object datatypes to categorical**

# %%
df.gender=pd.Categorical(df.gender).codes
df.gender
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 48655    1
# 48656    1
# 48657    0
# 48658    1
# 48659    1
# Name: gender, Length: 48660, dtype: int8

# %%
#convert department and education to 0s and 1s using get_dummies in pandas
department=pd.get_dummies(df.department,drop_first=True)
education=pd.get_dummies(df.education,drop_first=True)
df=pd.concat((df.drop(['education','department'],axis=1),department,education),axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-112-eadaab393d27> in <module>
#       1 #convert department and education to 0s and 1s using get_dummies in pandas
# ----> 2 department=pd.get_dummies(df.department,drop_first=True)
#       3 education=pd.get_dummies(df.education,drop_first=True)
#       4 df=pd.concat((df.drop(['education','department'],axis=1),department,education),axis=1)
#       5 df
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'department'

# %%
df.head()

# %%
# capture the target column ("default") into separate vectors for training set and test set
X = df.drop(["is_promoted",'employee_id'] , axis=1)
y = df.pop("is_promoted")

# %%
# splitting data into training and test set for independent attributes
from sklearn.model_selection import train_test_split

X_train, X_test, train_labels, test_labels = train_test_split(X, y, test_size=.30, random_state=1)

# %% [markdown]
# # Ensemble RandomForest Classifier

# %% [markdown]
# **Instantiate the Random Forest Classifier Class**

# %%
rfcl = RandomForestClassifier(n_estimators=501, random_state=123)
rfcl = rfcl.fit(X_train,train_labels )

# %% [markdown]
# **Perform Grid Search**

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [7, 10],
    'max_features': [4, 6],
    'min_samples_leaf': [50, 100],
    'min_samples_split': [150, 300],
    'n_estimators': [301, 501]
}

rfcl = RandomForestClassifier()

grid_search = GridSearchCV(estimator = rfcl, param_grid = param_grid, cv = 3)

# %%
grid_search.fit(X_train,train_labels )
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [7, 10], 'max_features': [4, 6],
#                          'min_samples_leaf': [50, 100],
#                          'min_samples_split': [150, 300],
#                          'n_estimators': [301, 501]})

# %% [markdown]
# **Get best parameters**

# %%
grid_search.best_params_
# Out:
# {'max_depth': 10,
#  'max_features': 6,
#  'min_samples_leaf': 50,
#  'min_samples_split': 150,
#  'n_estimators': 501}

# %%
best_grid = grid_search.best_estimator_

# %% [markdown]
# **Predict on both train and test sets**

# %%
ytrain_predict = best_grid.predict(X_train)

# %% [markdown]
# **Check Feature Importances**

# %%
x=pd.DataFrame(best_grid.feature_importances_*100,index=X_train.columns).sort_values(by=0,ascending=False)
plt.figure(figsize=(12,7))
sns.barplot(x[0],x.index,palette='dark')
plt.xlabel('Feature Importance in %')
plt.ylabel('Features')
plt.title('Feature Importance using RF')
plt.show()
x
# Out:
#                                0
# training_marks         55.755912
# all_tasks_completed    18.757014
# last_promotion_rating   9.487113
# Sales & Marketing       4.519272
# Operations              3.437392
# employee_since_years    1.875182
# age                     1.787725
# Technology              1.553869
# Procurement             0.897588
# gender                  0.602393
# Master's & above        0.502550
# no_of_trainings         0.306681
# Finance                 0.224550
# R&D                     0.137529
# Legal                   0.084781
# HR                      0.069434
# Below Secondary         0.001015

# %% [markdown]
# **Using Scikit-learn metrics, print confusion matrix and classification report**

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %% [markdown]
# **Plot ROC Curve and print area under the curve**

# %%
import matplotlib.pyplot as plt

# %%
# AUC and ROC for the training data

# predict probabilities
probs = best_grid.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(train_labels, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(train_labels, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# AUC: 0.901

# %%
# AUC and ROC for the test data
# predict probabilities
probs = best_grid.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(test_labels, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(test_labels, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# AUC: 0.885

# %% [markdown]
# ## Conclusion
